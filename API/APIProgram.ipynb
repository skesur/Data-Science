# %%
import requests
import json
import pandas as pd

# %%
d={
    "Ahmedavad":("23.033863","72.585022"),
    "Mumbai":("19.076090","72.877426"),
}
key="57ed3a63cbe79efa475d0ab0b2f29b27"
co=[]
no=[]
no2=[]
o3=[]
so2=[]
pm2_5=[]
pm10=[]
nh3=[]
for i in d:
    lat=d[i][0]
    lon=d[i][1]
    url=f"http://api.openweathermap.org/data/2.5/air_pollution?lat={lat}&lon={lon}&appid={key}"
    data=requests.get(url)
    new=data.json()
    print(new)
    for j in new["list"]:
        
    print(data.status_code)
# Out:
# {'coord': {'lon': 72.585, 'lat': 23.0339}, 'list': [{'main': {'aqi': 2}, 'components': {'co': 117.91, 'no': 0.17, 'no2': 1, 'o3': 97.25, 'so2': 2.63, 'pm2_5': 17.66, 'pm10': 43.7, 'nh3': 0.87}, 'dt': 1779433845}]}
# 200
# {'coord': {'lon': 72.8777, 'lat': 19.076}, 'list': [{'main': {'aqi': 1}, 'components': {'co': 81.83, 'no': 0.01, 'no2': 0.03, 'o3': 30.71, 'so2': 0.03, 'pm2_5': 0.59, 'pm10': 1.75, 'nh3': 0.21}, 'dt': 1779433662}]}
# 200

# %%
new=data.json()
final=json.dumps(new,indent=5)
print(final)
# Out:
# {
#      "coord": {
#           "lon": 72.5873,
#           "lat": 23.0258
#      },
#      "list": [
#           {
#                "main": {
#                     "aqi": 2
#                },
#                "components": {
#                     "co": 117.91,
#                     "no": 0.17,
#                     "no2": 1,
#                     "o3": 97.25,
#                     "so2": 2.63,
#                     "pm2_5": 17.66,
#                     "pm10": 43.7,
#                     "nh3": 0.87
#                },
#                "dt": 1779433219
#           }
#      ]
# }
