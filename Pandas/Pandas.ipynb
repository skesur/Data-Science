# %%
import pandas as pd

# %%
ls = [10,20,30,40,50]
l1 = pd.Series(ls)
l1
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
tp = (10,20,30,40,50)
t1 = pd.Series(tp)
l1
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
dic = {"Saumya":100,"Chintan":90,"Harsh":80}
d1 = pd.Series(dic)
d1
# Out:
# Saumya     100
# Chintan     90
# Harsh       80
# dtype: int64

# %%
li1 = ["Saumya","Chintan","Harsh"]
li2 = [10,9,8]
li = pd.Series(li2,index=li1,name="Score")
li
# Out:
# Saumya     10
# Chintan     9
# Harsh       8
# Name: Score, dtype: int64

# %%
li1 = [[10,20,30],[100,200,300]]
li = pd.DataFrame(li1)
li
# Out:
#      0    1    2
# 0   10   20   30
# 1  100  200  300

# %%
f = pd.read_csv("spotify.csv")
df1 = pd.DataFrame(f)
df1
# Out:
#         Unnamed: 0                track_id                 artists  \
# 0                0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1                1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2                2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3                3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4                4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
# ...            ...                     ...                     ...
# 113995      113995  2C3TZjDRiAzdyViavDJ217           Rainy Lullaby
# 113996      113996  1hIz5L4IB9hN3WRYPOCGPw           Rainy Lullaby
# 113997      113997  6x8ZfSoqDjuNa5SVP5QjvX           Cesária Evora
# 113998      113998  2e6sXL2bYv4bSz6VTdnfLs        Michael W. Smith
# 113999      113999  2hETkH7cOfqmz3LqZDHZf5           Cesária Evora
#
#                                                album_name  \
# 0                                                  Comedy
# ...

# %%
df1.shape
df1.shape[0]
df1.shape[1]
# Out:
# 21

# %%
df1.size
# Out:
# 2394000

# %%
df1.ndim
# Out:
# 2

# %%
df1.head()
# Out:
#    Unnamed: 0                track_id                 artists  \
# 0           0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1           1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2           2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3           3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4           4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
#
#                                           album_name  \
# 0                                             Comedy
# 1                                   Ghost (Acoustic)
# 2                                     To Begin Again
# 3  Crazy Rich Asians (Original Motion Picture Sou...
# 4                                            Hold On
#
#                    track_name  popularity  duration_ms  explicit  \
# 0                      Comedy          73       230666     False
# 1            Ghost - Acoustic          55       149610     False
# 2              To Begin Again          57       210826     False
# ...

# %%
df1.tail()
# Out:
#         Unnamed: 0                track_id           artists  \
# 113995      113995  2C3TZjDRiAzdyViavDJ217     Rainy Lullaby
# 113996      113996  1hIz5L4IB9hN3WRYPOCGPw     Rainy Lullaby
# 113997      113997  6x8ZfSoqDjuNa5SVP5QjvX     Cesária Evora
# 113998      113998  2e6sXL2bYv4bSz6VTdnfLs  Michael W. Smith
# 113999      113999  2hETkH7cOfqmz3LqZDHZf5     Cesária Evora
#
#                                                album_name  \
# 113995  #mindfulness - Soft Rain for Mindful Meditatio...
# 113996  #mindfulness - Soft Rain for Mindful Meditatio...
# 113997                                            Best Of
# 113998                                  Change Your World
# 113999                                     Miss Perfumado
#
#                  track_name  popularity  duration_ms  explicit  danceability  \
# 113995  Sleep My Little Boy          21       384999     False         0.172
# 113996     Water Into Light          22       385000     False         0.174
# ...

# %%
df1.info
# Out:
# <bound method DataFrame.info of         Unnamed: 0                track_id                 artists  \
# 0                0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1                1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2                2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3                3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4                4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
# ...            ...                     ...                     ...
# 113995      113995  2C3TZjDRiAzdyViavDJ217           Rainy Lullaby
# 113996      113996  1hIz5L4IB9hN3WRYPOCGPw           Rainy Lullaby
# 113997      113997  6x8ZfSoqDjuNa5SVP5QjvX           Cesária Evora
# 113998      113998  2e6sXL2bYv4bSz6VTdnfLs        Michael W. Smith
# 113999      113999  2hETkH7cOfqmz3LqZDHZf5           Cesária Evora
#
#                                                album_name  \
# 0                                                  Comedy
# ...

# %%
df1.isnull().sum()
# Out:
# Unnamed: 0          0
# track_id            0
# artists             1
# album_name          1
# track_name          1
# popularity          0
# duration_ms         0
# explicit            0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# time_signature      0
# track_genre         0
# dtype: int64

# %%
df1.iloc[::]
# Out:
#         Unnamed: 0                track_id                 artists  \
# 0                0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1                1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2                2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3                3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4                4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
# ...            ...                     ...                     ...
# 113995      113995  2C3TZjDRiAzdyViavDJ217           Rainy Lullaby
# 113996      113996  1hIz5L4IB9hN3WRYPOCGPw           Rainy Lullaby
# 113997      113997  6x8ZfSoqDjuNa5SVP5QjvX           Cesária Evora
# 113998      113998  2e6sXL2bYv4bSz6VTdnfLs        Michael W. Smith
# 113999      113999  2hETkH7cOfqmz3LqZDHZf5           Cesária Evora
#
#                                                album_name  \
# 0                                                  Comedy
# ...

# %%
df1.iloc[:5:,:4]
# Out:
#    Unnamed: 0                track_id                 artists  \
# 0           0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1           1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2           2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3           3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4           4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
#
#                                           album_name
# 0                                             Comedy
# 1                                   Ghost (Acoustic)
# 2                                     To Begin Again
# 3  Crazy Rich Asians (Original Motion Picture Sou...
# 4                                            Hold On

# %%
df1.iloc[::-1,::-1]
# Out:
#         track_genre  time_signature    tempo  valence  liveness  \
# 113999  world-music               4   79.198   0.7080    0.0893
# 113998  world-music               4  135.960   0.4130    0.2700
# 113997  world-music               4  132.378   0.7430    0.0839
# 113996  world-music               4   85.239   0.0350    0.1050
# 113995  world-music               5  125.995   0.0339    0.0863
# ...             ...             ...      ...      ...       ...
# 4          acoustic               4  119.949   0.1670    0.0829
# 3          acoustic               3  181.740   0.1430    0.1320
# 2          acoustic               4   76.332   0.1200    0.1170
# 1          acoustic               4   77.489   0.2670    0.1010
# 0          acoustic               4   87.917   0.7150    0.3580
#
#         instrumentalness  acousticness  speechiness  mode  loudness  ...  \
# 113999          0.000000        0.6810       0.0725     0   -10.204  ...
# ...

# %%
df1.loc[0:25,"track_id":"track_name"]
# Out:
#                   track_id                               artists  \
# 0   5SuOikwiRyPMVoIQDJUgSV                           Gen Hoshino
# 1   4qPNDBW1i3p13qLCt0Ki3A                          Ben Woodward
# 2   1iJBSr7s7jYXzM8EGcbK5b                Ingrid Michaelson;ZAYN
# 3   6lfxq3CG4xtTiEg7opyCyx                          Kina Grannis
# 4   5vjLSffimiIP26QG5WcN2K                      Chord Overstreet
# 5   01MVOl9KtVTNfFiBU9I7dc                          Tyrone Wells
# 6   6Vc5wAMmXdKIAM7WUoEb7N  A Great Big World;Christina Aguilera
# 7   1EzrEOXmMH3G43AXT1y7pA                            Jason Mraz
# 8   0IktbUcnAGrvD03AWnz3Q8             Jason Mraz;Colbie Caillat
# 9   7k9GuJYLp2AzqokyEdwEw2                        Ross Copperman
# 10  4mzP5mHkRvGxdhdGdAH7EJ                          Zack Tabudlo
# 11  5ivF4eQBqJiVL5IAE9jRyl                            Jason Mraz
# 12  4ptDJbJl35d7gQfeNteBwp                              Dan Berk
# ...

# %%
df1
# Out:
#         Unnamed: 0                track_id                 artists  \
# 0                0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1                1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2                2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3                3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4                4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
# ...            ...                     ...                     ...
# 113995      113995  2C3TZjDRiAzdyViavDJ217           Rainy Lullaby
# 113996      113996  1hIz5L4IB9hN3WRYPOCGPw           Rainy Lullaby
# 113997      113997  6x8ZfSoqDjuNa5SVP5QjvX           Cesária Evora
# 113998      113998  2e6sXL2bYv4bSz6VTdnfLs        Michael W. Smith
# 113999      113999  2hETkH7cOfqmz3LqZDHZf5           Cesária Evora
#
#                                                album_name  \
# 0                                                  Comedy
# ...

# %%
df1["track_name"]
# Out:
# 0                             Comedy
# 1                   Ghost - Acoustic
# 2                     To Begin Again
# 3         Can't Help Falling In Love
# 4                            Hold On
#                      ...
# 113995           Sleep My Little Boy
# 113996              Water Into Light
# 113997                Miss Perfumado
# 113998                       Friends
# 113999                     Barbincor
# Name: track_name, Length: 114000, dtype: object

# %%
df1[(df1["artists"]=="Gen Hoshino")&((df1["duration_ms"]>200000)|(df1["duration_ms"]>250000))]
# Out:
#         Unnamed: 0                track_id      artists  \
# 0                0  5SuOikwiRyPMVoIQDJUgSV  Gen Hoshino
# 406            406  4nmjL1mUKOAfAbo9QG9tSE  Gen Hoshino
# 663            663  12qmPGMrOCogibc7qyxT9s  Gen Hoshino
# 751            751  3dPpQeLTWjCjEbSevDMQfW  Gen Hoshino
# 756            756  2pcuXnZhTirLXsfXGVFTv2  Gen Hoshino
# 800            800  7rIBp3U5Igzn44l7Z7mOtE  Gen Hoshino
# 62102        62102  5SuOikwiRyPMVoIQDJUgSV  Gen Hoshino
# 99152        99152  5SuOikwiRyPMVoIQDJUgSV  Gen Hoshino
# 102151      102151  5SuOikwiRyPMVoIQDJUgSV  Gen Hoshino
#
#                                   album_name  \
# 0                                     Comedy
# 406                                POP VIRUS
# 663     I Wanna Be Your Ghost (feat. Ghosts)
# 751                                  FUSHIGI
# 756                                 Doraemon
# 800                            YELLOW DANCER
# 62102                                 Comedy
# ...

# %%
f = pd.read_csv("ipl-matches.csv")
df = pd.DataFrame(f)
df
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
df[df["SuperOver"]=="Y"].count().max()
# Out:
# 14

# %%
df[(df["WinningTeam"]=="Chennai Super Kings")&(df["City"]=="Kolkata")].count().max()
# Out:
# 5

# %%
df[((df["Team1"]=="Mumbai Indians")|(df["Team2"]=="Mumbai Indians"))&(df["Player_of_Match"]=="MS Dhoni")].count().max()
# Out:
# 1

# %%
df[(df["WinningTeam"]=="Gujarat Titans")&(df["TossWinner"]=="Gujarat Titans")&(df["TossDecision"]=="bat")].count().max()
# Out:
# 2

# %%
df[df["WinningTeam"]=="Gujarat Titans"].count().max()
# Out:
# 12

# %%
df1 = pd.DataFrame({
    "ID":[1,2,3],
    "Name":["A","B","C"]
})
df2 = pd.DataFrame({
    "ID":[2,3,4],
    "Marks":[80,90,70]
})
df = pd.concat([df1,df2],join="outer")
df
# Out:
#    ID Name  Marks
# 0   1    A    NaN
# 1   2    B    NaN
# 2   3    C    NaN
# 0   2  NaN   80.0
# 1   3  NaN   90.0
# 2   4  NaN   70.0

# %%
df.isnull().sum()
# Out:
# ID       0
# Name     3
# Marks    3
# dtype: int64

# %%
df.sort_values(by="ID")
# Out:
#    ID Name  Marks
# 0   1    A    NaN
# 1   2    B    NaN
# 0   2  NaN   80.0
# 2   3    C    NaN
# 1   3  NaN   90.0
# 2   4  NaN   70.0

# %%
df = pd.DataFrame({
    "Dept":["IT","IT","HR","HR","Finance","Finance"],
    "Salary":[50000,70000,40000,60000,80000,70000]
})
df
# Out:
#       Dept  Salary
# 0       IT   50000
# 1       IT   70000
# 2       HR   40000
# 3       HR   60000
# 4  Finance   80000
# 5  Finance   70000

# %%
df.groupby("Dept").agg(["mean","median","max","sum"])
# Out:
#         Salary
#           mean median    max     sum
# Dept
# Finance  75000  75000  80000  150000
# HR       50000  50000  60000  100000
# IT       60000  60000  70000  120000

# %%
f = pd.read_csv("movies.csv")
df = pd.DataFrame(f)
df
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
df[df["year_of_release"]==2019].shape[0]
# Out:
# 75

# %%
df[df["imdb_rating"]>7][["title_x"]].shape[0]
# Out:
# 331

# %%
df[df["imdb_votes"]>20000].shape[0]
# Out:
# 105

# %%
df[df["year_of_release"]==2018][["title_x"]]
# Out:
#                         title_x
# 4               Evening Shadows
# 5                   Soni (film)
# 16       Mard Ko Dard Nahi Hota
# 17                 Hamid (film)
# 20    Mere Pyare Prime Minister
# ...                         ...
# 156                Rajma Chawal
# 157            Zero (2018 film)
# 158                      Simmba
# 166          Thugs of Hindostan
# 1626            Sabse Bada Sukh
#
# [79 rows x 1 columns]

# %%
df = pd.DataFrame({
    "Student":["A","B","C","D"],
    "Math":[70,45,90,60],
    "Science":[75,40,85,55]
})

df
# Out:
#   Student  Math  Science
# 0       A    70       75
# 1       B    45       40
# 2       C    90       85
# 3       D    60       55

# %%
avg = df[["Math","Science"]].mean(axis=1)
df["Avg"]=avg.apply(lambda x:x)
df
# Out:
#   Student  Math  Science   Avg
# 0       A    70       75  72.5
# 1       B    45       40  42.5
# 2       C    90       85  87.5
# 3       D    60       55  57.5
