# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import seaborn as sns

# %%
df = pd.DataFrame(pd.read_csv("cancer.csv"));
df.drop(["id","Unnamed: 32"],axis=1,inplace=True)
df
# Out:
#     diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  ...  compactness_worst  concavity_worst  concave points_worst  symmetry_worst  fractal_dimension_worst
# 0           M        17.99         10.38          122.80     1001.0  ...            0.66560           0.7119                0.2654          0.4601                  0.11890
# 1           M        20.57         17.77          132.90     1326.0  ...            0.18660           0.2416                0.1860          0.2750                  0.08902
# 2           M        19.69         21.25          130.00     1203.0  ...            0.42450           0.4504                0.2430          0.3613                  0.08758
# 3           M        11.42         20.38           77.58      386.1  ...            0.86630           0.6869                0.2575          0.6638                  0.17300
# ...

# %%
x = df.drop(["diagnosis"],axis=1)
y = df["diagnosis"]
x = pd.get_dummies(x)
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=42)
model = RandomForestClassifier(criterion="entropy",max_depth=3,n_estimators=5,random_state=42)
model.fit(x_train,y_train)
pre = model.predict(x_test)
print(accuracy_score(y_test,pre))
print(classification_report(y_test,pre))
print(confusion_matrix(y_test,pre))
# Out:
# 0.9385964912280702
#               precision    recall  f1-score   support
#
#            B       0.93      0.97      0.95        71
#            M       0.95      0.88      0.92        43
#
#     accuracy                           0.94       114
#    macro avg       0.94      0.93      0.93       114
# weighted avg       0.94      0.94      0.94       114
#
# [[69  2]
#  [ 5 38]]

# %%
dic = {}
for i in range(1,50):
    model = RandomForestClassifier(criterion="entropy",max_depth=3,n_estimators=i,random_state=42)
    model.fit(x_train,y_train)
    pre = model.predict(x_test)
    dic[i] = accuracy_score(y_test,pre)
max_key = max(dic,key=dic.get)
print(max_key,dic[max_key])
# Out:
# 14 0.9649122807017544
